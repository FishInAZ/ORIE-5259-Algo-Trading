# %%
import numpy as np
import pandas as pd

from pathlib import Path
from sklearn.linear_model import Ridge
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error, r2_score

import matplotlib.pyplot as plt

# %%
# Load signals from Multi_Factor_strategy
df = pd.read_csv("model_df.csv")
df.head()
# Out:
#            Time  BidPrice_5  BidPrice_4  BidPrice_3  BidPrice_2  BidPrice_1  \
# 0  09:30:00.017      222.62       223.0      223.04      223.07      223.18
# 1  09:30:00.189      223.50       223.6      223.65      223.75      223.81
# 2  09:30:00.189      223.50       223.6      223.65      223.75      223.81
# 3  09:30:00.189      223.50       223.6      223.65      223.75      223.81
# 4  09:30:00.189      223.50       223.6      223.65      223.75      223.81
#
#    BidSize_5  BidSize_4  BidSize_3  BidSize_2  ...  event_idx_in_min  \
# 0        100         10        100        200  ...                 0
# 1        100         15          2        100  ...                 1
# 2        100         15          2        100  ...                 2
# 3        100         15          2        100  ...                 3
# 4        100         15          2        100  ...                 4
#
#    n_events_in_min  event_frac_in_min  future_min_ask_in_min  buy_regret  \
# 0              722           0.000000                 223.86        0.09
# 1              722           0.001387                 223.86        0.09
# 2              722           0.002774                 223.86        0.09
# 3              722           0.004161                 223.86        0.09
# 4              722           0.005548                 223.86        0.09
#
#    future_max_bid_in_min  sell_regret  stock_GOOG  stock_INTC  stock_MSFT
# 0                 224.29         1.11       False       False       False
# 1                 224.29         0.48       False       False       False
# 2                 224.29         0.48       False       False       False
# 3                 224.29         0.48       False       False       False
# 4                 224.29         0.48       False       False       False
#
# [5 rows x 72 columns]

# %%
df.columns
# Out:
# Index(['Time', 'BidPrice_5', 'BidPrice_4', 'BidPrice_3', 'BidPrice_2',
#        'BidPrice_1', 'BidSize_5', 'BidSize_4', 'BidSize_3', 'BidSize_2',
#        'BidSize_1', 'AskPrice_1', 'AskPrice_2', 'AskPrice_3', 'AskPrice_4',
#        'AskPrice_5', 'AskSize_1', 'AskSize_2', 'AskSize_3', 'AskSize_4',
#        'AskSize_5', 'OrderID', 'Size', 'Price', 'Direction_1=Buy_-1=Sell',
#        'NewLimitOrder_1=Yes_0=No', 'PartialCancel_1=Yes_0=No',
#        'FullDelete_1=Yes_0=No', 'VisibleExecution_1=Yes_0=No',
#        'HiddenExecution_1=Yes_0=No', 'TradingHalt_1=Yes_0=No', 'Spread',
#        'MidPrice', 'ts', 'minute', 'sec_in_min', 'bid1', 'ask1', 'bsz1',
#        'asz1', 'mid', 'spread', 'bid_liq_1', 'ask_liq_1', 'depth_value_1',
#        'imbalance_1', 'microprice', 'micro_minus_mid', 'total_bid_size_5',
#        'total_ask_size_5', 'imbalance_5', 'wap_bid_5', 'wap_ask_5', 'mid_chg1',
#        'spread_chg1', 'imbalance_1_chg1', 'imbalance_5_chg1',
#        'micro_minus_mid_chg1', 'bid_liq_1_chg1', 'ask_liq_1_chg1',
#        'total_bid_size_5_chg1', 'total_ask_size_5_chg1', 'event_idx_in_min',
#        'n_events_in_min', 'event_frac_in_min', 'future_min_ask_in_min',
#        'buy_regret', 'future_max_bid_in_min', 'sell_regret', 'stock_GOOG',
#        'stock_INTC', 'stock_MSFT'],
#       dtype='object')
